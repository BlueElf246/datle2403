# %% [markdown]
# <a href="https://colab.research.google.com/github/datle2403/datle2403/blob/main/LAB05_Nguy%E1%BB%85n_Th%E1%BA%A1ch_H%C3%A0_Anh.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !pip install beautifulsoup4
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import requests #Lấy dữ liệu
from bs4 import BeautifulSoup
# Truy cập đường link -> Lấy ra Table -> Lưu vào trong file đó.

# %%
link_base = "https://tygiadola.net/LichSuGiaVang?date="
list_link = []
#Lấy dữ liệu từ năm tùy chỉnh đến năm tùy chỉnh.
#Trong demo này lấy từ năm 2018 đến thời điểm hiện tại 2022.
#Custom
start_year = 2018
current_year = 2022
month_current = 10
day_current = 25
for year in range(start_year, current_year + 1):
    if year < current_year:
        if year % 4 == 0:
            for month in range(1, 12 + 1):
                if month < 10:
                    if month == 2:
                        for day in range(1, 29 + 1):
                            if day < 10:
                                item = link_base + "0" + str(day) + "-0" + str(month) + "-" + str(year)
                                list_link.append(item)
                            else:
                                item = link_base + str(day) + "-0" + str(month) + "-" + str(year)
                                list_link.append(item)
                    elif (month == 1) or (month == 3) or (month == 5) or (month == 7) or (month == 8):
                        for day in range(1, 31 + 1):
                            if day < 10:
                                item = link_base + "0" + str(day) + "-0" + str(month) + "-" + str(year)
                                list_link.append(item)
                            else:
                                item = link_base + str(day) + "-0" + str(month) + "-" + str(year)
                                list_link.append(item)
                    else:
                        for day in range(1, 30 + 1):
                            if day < 10:
                                item = link_base + "0" + str(day) + "-0" + str(month) + "-" + str(year)
                                list_link.append(item)
                            else:
                                item = link_base + str(day) + "-0" + str(month) + "-" + str(year)
                                list_link.append(item)
                else:
                    if (month == 10) or (month == 12):
                        for day in range(1, 31 + 1):
                            if day < 10:
                                item = link_base + "0" + str(day) + "-" + str(month) + "-" + str(year)
                                list_link.append(item)
                            else:
                                item = link_base + str(day) + "-" + str(month) + "-" + str(year)
                                list_link.append(item)
                    else:
                        for day in range(1, 30 + 1):
                            if day < 10:
                                item = link_base + "0" + str(day) + "-" + str(month) + "-" + str(year)
                                list_link.append(item)
                            else:
                                item = link_base + str(day) + "-" + str(month) + "-" + str(year)
                                list_link.append(item)
        elif year % 4 != 0:
            for month in range(1, 12 + 1):
                if month < 10:
                    if month == 2:
                        for day in range(1, 28 + 1):
                            if day < 10:
                                item = link_base + "0" + str(day) + "-0" + str(month) + "-" + str(year)
                                list_link.append(item)
                            else:
                                item = link_base + str(day) + "-0" + str(month) + "-" + str(year)
                                list_link.append(item)
                    elif (month == 1) or (month == 3) or (month == 5) or (month == 7) or (month == 8):
                        for day in range(1, 31 + 1):
                            if day < 10:
                                item = link_base + "0" + str(day) + "-0" + str(month) + "-" + str(year)
                                list_link.append(item)
                            else:
                                item = link_base + str(day) + "-0" + str(month) + "-" + str(year)
                                list_link.append(item)
                    else:
                        for day in range(1, 30 + 1):
                            if day < 10:
                                item = link_base + "0" + str(day) + "-0" + str(month) + "-" + str(year)
                                list_link.append(item)
                            else:
                                item = link_base + str(day) + "-0" + str(month) + "-" + str(year)
                                list_link.append(item)
                else:
                    if (month == 10) or (month == 12):
                        for day in range(1, 31 + 1):
                            if day < 10:
                                item = link_base + "0" + str(day) + "-" + str(month) + "-" + str(year)
                                list_link.append(item)
                            else:
                                item = link_base + str(day) + "-" + str(month) + "-" + str(year)
                                list_link.append(item)
                    else:
                        for day in range(1, 30 + 1):
                            if day < 10:
                                item = link_base + "0" + str(day) + "-" + str(month) + "-" + str(year)
                                list_link.append(item)
                            else:
                                item = link_base + str(day) + "-" + str(month) + "-" + str(year)
                                list_link.append(item)
  
    #Thời điểm hiện tại
    elif year == current_year:
        if year % 4 == 0:
            for month in range(1, month_current + 1):
              if month < month_current:
                if month < 10:
                    if month == 2:
                        for day in range(1, 29 + 1):
                            if day < 10:
                                item = link_base + "0" + str(day) + "-0" + str(month) + "-" + str(year)
                                list_link.append(item)
                            else:
                                item = link_base + str(day) + "-0" + str(month) + "-" + str(year)
                                list_link.append(item)
                    elif (month == 1) or (month == 3) or (month == 5) or (month == 7) or (month == 8):
                        for day in range(1, 31 + 1):
                            if day < 10:
                                item = link_base + "0" + str(day) + "-0" + str(month) + "-" + str(year)
                                list_link.append(item)
                            else:
                                item = link_base + str(day) + "-0" + str(month) + "-" + str(year)
                                list_link.append(item)
                    else:
                        for day in range(1, 30 + 1):
                            if day < 10:
                                item = link_base + "0" + str(day) + "-0" + str(month) + "-" + str(year)
                                list_link.append(item)
                            else:
                                item = link_base + str(day) + "-0" + str(month) + "-" + str(year)
                                list_link.append(item)
                else:
                    if (month == 10) or (month == 12):
                        for day in range(1, 31 + 1):
                            if day < 10:
                                item = link_base + "0" + str(day) + "-" + str(month) + "-" + str(year)
                                list_link.append(item)
                            else:
                                item = link_base + str(day) + "-" + str(month) + "-" + str(year)
                                list_link.append(item)
                    else:
                        for day in range(1, 30 + 1):
                            if day < 10:
                                item = link_base + "0" + str(day) + "-" + str(month) + "-" + str(year)
                                list_link.append(item)
                            else:
                                item = link_base + str(day) + "-" + str(month) + "-" + str(year)
                                list_link.append(item)
              #Trong trường hợp lấy từ ngày trong năm
              elif month == month_current:
                if month < 10:
                  for day in range(1, day_current + 1):
                    if day < 10:
                      item = link_base + "0" + str(day) + "-0" + str(month) + "-" + str(year)
                      list_link.append(item)
                    else:
                      item = link_base + str(day) + "-0" + str(month) + "-" + str(year)
                      list_link.append(item)
                else:
                  for day in range(1, day_current + 1):
                    if day < 10:
                      item = link_base + "0" + str(day) + "-" + str(month) + "-" + str(year)
                      list_link.append(item)
                    else:
                      item = link_base + str(day) + "-" + str(month) + "-" + str(year)
                      list_link.append(item)

        elif year % 4 != 0:            
          for month in range(1, month_current + 1):
              if month < month_current:
                if month < 10:
                    if month == 2:
                        for day in range(1, 28 + 1):
                            if day < 10:
                                item = link_base + "0" + str(day) + "-0" + str(month) + "-" + str(year)
                                list_link.append(item)
                            else:
                                item = link_base + str(day) + "-0" + str(month) + "-" + str(year)
                                list_link.append(item)
                    elif (month == 1) or (month == 3) or (month == 5) or (month == 7) or (month == 8):
                        for day in range(1, 31 + 1):
                            if day < 10:
                                item = link_base + "0" + str(day) + "-0" + str(month) + "-" + str(year)
                                list_link.append(item)
                            else:
                                item = link_base + str(day) + "-0" + str(month) + "-" + str(year)
                                list_link.append(item)
                    else:
                        for day in range(1, 30 + 1):
                            if day < 10:
                                item = link_base + "0" + str(day) + "-0" + str(month) + "-" + str(year)
                                list_link.append(item)
                            else:
                                item = link_base + str(day) + "-0" + str(month) + "-" + str(year)
                                list_link.append(item)
                else:
                    if (month == 10) or (month == 12):
                        for day in range(1, 31 + 1):
                            if day < 10:
                                item = link_base + "0" + str(day) + "-" + str(month) + "-" + str(year)
                                list_link.append(item)
                            else:
                                item = link_base + str(day) + "-" + str(month) + "-" + str(year)
                                list_link.append(item)
                    else:
                        for day in range(1, 30 + 1):
                            if day < 10:
                                item = link_base + "0" + str(day) + "-" + str(month) + "-" + str(year)
                                list_link.append(item)
                            else:
                                item = link_base + str(day) + "-" + str(month) + "-" + str(year)
                                list_link.append(item)
              #Trong trường hợp lấy từ ngày trong năm
              elif month == month_current:
                if month < 10:
                  for day in range(1, day_current + 1):
                    if day < 10:
                      item = link_base + "0" + str(day) + "-0" + str(month) + "-" + str(year)
                      list_link.append(item)
                    else:
                      item = link_base + str(day) + "-0" + str(month) + "-" + str(year)
                      list_link.append(item)
                else:
                  for day in range(1, day_current + 1):
                    if day < 10:
                      item = link_base + "0" + str(day) + "-" + str(month) + "-" + str(year)
                      list_link.append(item)
                    else:
                      item = link_base + str(day) + "-" + str(month) + "-" + str(year)
                      list_link.append(item)
      
print(list_link)
# Out:
# https://tygiadola.net/LichSuGiaVang?date=01-01-2018
# https://tygiadola.net/LichSuGiaVang?date=02-01-2018
# https://tygiadola.net/LichSuGiaVang?date=03-01-2018
# https://tygiadola.net/LichSuGiaVang?date=04-01-2018
# https://tygiadola.net/LichSuGiaVang?date=05-01-2018
# https://tygiadola.net/LichSuGiaVang?date=06-01-2018
# https://tygiadola.net/LichSuGiaVang?date=07-01-2018
# https://tygiadola.net/LichSuGiaVang?date=08-01-2018
# https://tygiadola.net/LichSuGiaVang?date=09-01-2018
# https://tygiadola.net/LichSuGiaVang?date=10-01-2018
# https://tygiadola.net/LichSuGiaVang?date=11-01-2018
# https://tygiadola.net/LichSuGiaVang?date=12-01-2018
# https://tygiadola.net/LichSuGiaVang?date=13-01-2018
# https://tygiadola.net/LichSuGiaVang?date=14-01-2018
# https://tygiadola.net/LichSuGiaVang?date=15-01-2018
# https://tygiadola.net/LichSuGiaVang?date=16-01-2018
# https://tygiadola.net/LichSuGiaVang?date=17-01-2018
# https://tygiadola.net/LichSuGiaVang?date=18-01-2018
# ...

# %%
# Test thử đường link
# Có nhiều trang web phát hiện ra trình duyệt có phải Robot hay không?
# Cần: add header request Python like Chrome -> Fake trình duyệt
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
for i in range(len(list_link)):
  link = list_link[i]
  r = requests.get(link, headers=headers)
  soup = BeautifulSoup(r.text, 'html.parser')
  # In bảng thử và lấy tbody trong Table
  # table_data = soup.find_all("table")
  # tbody = table_data[0].find("tbody")
  # print = (table_data[0].find("tbody"))
  tr_data = soup.find_all("tr", class_ ='')
  
  # print(tr_data)
  for row in tr_data[3:]:
    td_list = row.find_all("td")
    if len(y)==1:
      continue
    data = [td.text.strip() for td in td_list]
    print(data)

  print
  #str1 = f"{}, {}, {}"
# Out:
# Streaming output truncated to the last 5000 lines.
# ['DOJI HN', '36,91010', '36,9800']
# ['PNJ HCM', '36,7500', '37,0500']
# ['PNJ Hà Nội', '36,900100', '37,02036,650']
# ['Phú Qúy SJC', '36,90010', '36,98010']
# ['Bảo Tín Minh Châu', '36,910150', '36,970140']
# ['EXIMBANK', '36,910170', '36,970170']
# ['SCB', '36,85050', '36,9500']
# ['TPBANK GOLD', '36,860-40', '37,03040']
# ['Vàng nữ trang 24K', '36,003-20', '36,703-20']
# ['Vàng nữ trang 18K', '26,555-15', '27,955-15']
# ['Vàng nữ trang 14K', '20,364-12', '21,764-12']
# ['Vàng nữ trang 10K', '14,210-8', '15,610-8']
# ['SJC Hà Nội', '36,8400', '37,040-20']
# ['SJC Đà Nẵng', '36,8400', '37,040-20']
# ['(adsbygoogle = window.adsbygoogle || []).push({});']
# ['SJC Nha Trang', '36,8300', '37,040-20']
# ['SJC Cà Mau', '36,8400', '37,040-20']
# ['SJC Bình Phước', '36,8100', '37,050-20']
# ['SJC Huế', '36,8400', '37,040-20']
# ['SJC Biên Hòa', '36,8400', '37,020-20']
# ['SJC Miền Tây', '36,8400', '37,020-20']
# ...
